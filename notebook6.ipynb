# %% [markdown]
# #Análisis de Datos con Pandas

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("/content/hotel_bookings.csv")
dataset.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# # dimension de la tabla

# %%
dataset.shape
# Out:
# (119390, 32)

# %%
dataset.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
dataset['hotel']
# Out:
# 0         Resort Hotel
# 1         Resort Hotel
# 2         Resort Hotel
# 3         Resort Hotel
# 4         Resort Hotel
#               ...
# 119385      City Hotel
# 119386      City Hotel
# 119387      City Hotel
# 119388      City Hotel
# 119389      City Hotel
# Name: hotel, Length: 119390, dtype: object

# %%
dataset['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
dataset['hotel'].value_counts(normalize=True)
# Out:
# City Hotel      0.664461
# Resort Hotel    0.335539
# Name: hotel, dtype: float64

# %%
dataset['country'].value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, Length: 177, dtype: int64

# %%
dataset[(dataset['country'] == 'GTM') & (dataset['arrival_date_month'] == 'August') & (dataset['lead_time']>= 90)]

# %%
# reservas en España y que no lleven niños
dataset[(dataset['country'] == 'ESP') & (dataset['children'] == 0) & (dataset['babies']== 0)]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 36      Resort Hotel            0         15               2015
# 42      Resort Hotel            0         16               2015
# 46      Resort Hotel            0         96               2015
# 53      Resort Hotel            0          3               2015
# 62      Resort Hotel            0         17               2015
# ...              ...          ...        ...                ...
# 119060    City Hotel            0        233               2017
# 119125    City Hotel            0        181               2017
# 119158    City Hotel            0        180               2017
# 119343    City Hotel            0        149               2017
# 119346    City Hotel            0         45               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 36                   July                        27
# 42                   July                        27
# ...

# %%
dataset[(dataset['country'].isin(['ESP', 'FRA'])) & (dataset['children'] == 0) & (dataset['babies'] == 0)]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 18      Resort Hotel            0          0               2015
# 36      Resort Hotel            0         15               2015
# 42      Resort Hotel            0         16               2015
# 46      Resort Hotel            0         96               2015
# 53      Resort Hotel            0          3               2015
# ...              ...          ...        ...                ...
# 119288    City Hotel            0         44               2017
# 119312    City Hotel            0          4               2017
# 119343    City Hotel            0        149               2017
# 119346    City Hotel            0         45               2017
# 119386    City Hotel            0        102               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 18                   July                        27
# 36                   July                        27
# ...

# %%
dataset[(dataset['country'].isin(['ESP', 'FRA'])) & (dataset['children'] == 0) & (dataset['babies'] == 0)]

# %%
dataset['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
# para las reservas que incluyen
dataset[dataset['country'].isnull()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 30      Resort Hotel            0        118               2015
# 4127    Resort Hotel            1          0               2016
# 7092    Resort Hotel            1          8               2016
# 7860    Resort Hotel            1         39               2016
# 8779    Resort Hotel            1          0               2016
# ...              ...          ...        ...                ...
# 65908     City Hotel            1          0               2017
# 65909     City Hotel            1          0               2017
# 65910     City Hotel            1          0               2017
# 80830     City Hotel            0          4               2015
# 101488    City Hotel            0          1               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 30                   July                        27
# 4127             February                         8
# ...

# %%
dataset['country'].isnull().sum()
# Out:
# 488

# %%
dataset['country'].isnull().mean()
# Out:
# 0.004087444509590418

# %%
columnas= dataset.columns
for col in columnas:
  porcentaje = dataset[col].isnull().mean()
  if(porcentaje > 0):
    print(f"{col}: {porcentaje}")
# Out:
# children: 3.350364352123293e-05
# country: 0.004087444509590418
# agent: 0.13686238378423654
# company: 0.943068933746545

# %%
dataset['company'].value_counts()
# Out:
# 40.0     927
# 223.0    784
# 67.0     267
# 45.0     250
# 153.0    215
#         ...
# 104.0      1
# 531.0      1
# 160.0      1
# 413.0      1
# 386.0      1
# Name: company, Length: 352, dtype: int64

# %%
# datos con nans
dataset[dataset['country'].isnull()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 30      Resort Hotel            0        118               2015
# 4127    Resort Hotel            1          0               2016
# 7092    Resort Hotel            1          8               2016
# 7860    Resort Hotel            1         39               2016
# 8779    Resort Hotel            1          0               2016
# ...              ...          ...        ...                ...
# 65908     City Hotel            1          0               2017
# 65909     City Hotel            1          0               2017
# 65910     City Hotel            1          0               2017
# 80830     City Hotel            0          4               2015
# 101488    City Hotel            0          1               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 30                   July                        27
# 4127             February                         8
# ...

# %%
# datos sin nans

# %%
dataset[~dataset['country'].isnull()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
dataset.dropna()
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2392    Resort Hotel            0          6               2015
# 2697    Resort Hotel            0         24               2015
# 2867    Resort Hotel            0         24               2015
# 2877    Resort Hotel            0         24               2015
# 2878    Resort Hotel            0         24               2015
# ...              ...          ...        ...                ...
# 112499    City Hotel            0         13               2017
# 113046    City Hotel            0         13               2017
# 113082    City Hotel            0         13               2017
# 113627    City Hotel            0        210               2017
# 116451    City Hotel            0        191               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2392              October                        42
# 2697              October                        44
# ...

# %%
dataset.drop('company', axis= 1, inplace=True)
dataset.dropna()
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 7       Resort Hotel            0          9               2015
# 8       Resort Hotel            1         85               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 3                    July                        27
# 4                    July                        27
# ...

# %%
media_agent = dataset['agent'].mean()
# imputamos valor de la media en columna agent.
dataset['agent'].fillna(media_agent, inplace=True)

# %% [markdown]
# ### Estádisticas y Agregación

# %%
dataset.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
len(dataset['is_canceled'].unique())
# Out:
# 2

# %%
def get_variables_scale_type(dataset):
  columnas = dataset.columns
  categoricas = []
  continuas = []
  discretas = []
  for col in columnas :
  col_type = dataset[col].dtype()
  n = len(dataset[col].unique())
    if(col_type == 'object'):
      categoricas.append(col)
    elif((col_type == 'int64') or (col_type == 'float64')):
      n= len(dataset[col].unique())
      if(n>30):
        continuas.append(col)
      else
      discretas.append(col)
return continuas, discretas categoricas

# %%
continuas, discretas, categoricas = get_variables_scale_type(dataset)

# %%
import matplotlib as plt
import seaborn as sns

# %%
for col in continuas:
    df_describe = dataset[col].describe()
    print(col + ":")
    print("minimo", df_describe['min']
    print("media", df_describe['mean']
    print("Mediana", df_describe['50%']
    print("Maximo", df_describe['max']
    print("Desviacion", df_describe['std']
    print("Varianza", df_describe['std']**2)
    print("---------------------------")
    #plt.plot(dataset[col].plot.density(color = 'red'))
    #plt.title("adaad")
    #plt.show()
    sns.displot(dataset[col])
    print()

# %%
dataset['lead_time'].describe()
# Out:
# count    119390.000000
# mean        104.011416
# std         106.863097
# min           0.000000
# 25%          18.000000
# 50%          69.000000
# 75%         160.000000
# max         737.000000
# Name: lead_time, dtype: float64
